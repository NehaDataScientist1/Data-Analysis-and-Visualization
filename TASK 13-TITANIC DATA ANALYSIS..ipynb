# %% [markdown]
# # TITANIC DATA ANALYSIS (Data Processing):
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np

# %%
titanic=pd.read_csv(r'C:\Users\Neha\Downloads\NARESH IT DATA SCIENCE\MARCH\1-8 MARCH\2 MAR\DATA PREPROCSSING\DATASET\train.csv')

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic=pd.read_csv(r'C:\Users\Neha\Downloads\NARESH IT DATA SCIENCE\MARCH\1-8 MARCH\2 MAR\DATA PREPROCSSING\DATASET\train.csv', header = 0, dtype={'Age': np.float64})
titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # Performing Data Cleaning and Analysis
#
# 1. Understanding meaning of each column:
# Data Dictionary:
# Variable Description
#
# * Survived - Survived (1) or died (0)
# * Pclass - Passenger’s class (1 = 1st, 2 = 2nd, 3 = 3rd)
# * Name - Passenger’s name
# * Sex - Passenger’s sex
# * Age - Passenger’s age
# * SibSp - Number of siblings/spouses aboard
# * Parch - Number of parents/children aboard (Some children travelled *only with a nanny, therefore parch=0 for them.)
# * Ticket - Ticket number
# * Fare - Fare
# * Cabin - Cabin
# * Embarked - Port of embarkation (C = Cherbourg, Q = Queenstown, S = Southampton)
#
# 2. Analysing which columns are completely useless in predicting the survival and deleting them
# Note - Don't just delete the columns because you are not finding it useful. Or focus is not on deleting the columns. Our focus is on analysing how each column is affecting the result or the prediction and in accordance with that deciding whether to keep the column or to delete the column or fill the null values of the column by some values and if yes, then what values.

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#Name column can never decide survival of a person, hence we can safely delete it
del titanic['Name']
titanic.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
titanic[['Ticket']]
# Out:
#                Ticket
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# ..                ...
# 886            211536
# 887            112053
# 888        W./C. 6607
# 889            111369
# 890            370376
#
# [891 rows x 1 columns]

# %%
del titanic['Ticket']

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# 0            1         0       3    male  22.0      1      0   7.2500   NaN
# 1            2         1       1  female  38.0      1      0  71.2833   C85
# 2            3         1       3  female  26.0      0      0   7.9250   NaN
# 3            4         1       1  female  35.0      1      0  53.1000  C123
# 4            5         0       3    male  35.0      0      0   8.0500   NaN
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %%
del titanic['Fare']

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Cabin Embarked
# 0            1         0       3    male  22.0      1      0   NaN        S
# 1            2         1       1  female  38.0      1      0   C85        C
# 2            3         1       3  female  26.0      0      0   NaN        S
# 3            4         1       1  female  35.0      1      0  C123        S
# 4            5         0       3    male  35.0      0      0   NaN        S

# %%
del titanic['Cabin']
titanic.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Embarked
# 0            1         0       3    male  22.0      1      0        S
# 1            2         1       1  female  38.0      1      0        C
# 2            3         1       3  female  26.0      0      0        S
# 3            4         1       1  female  35.0      1      0        S
# 4            5         0       3    male  35.0      0      0        S

# %%
# Changing Value for "Male, Female" string values to numeric values , male=1 and female=2
def get_age_number(str):
    if str=='male':
        return 1
    else:
        return 2
titanic["Gender"]=titanic["Sex"].apply(get_age_number)

# %%
#We have created a new column called "Gender" and 
#filling it with values 1,2 based on the values of sex column
titanic.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Embarked  Gender
# 0            1         0       3    male  22.0      1      0        S       1
# 1            2         1       1  female  38.0      1      0        C       2
# 2            3         1       3  female  26.0      0      0        S       2
# 3            4         1       1  female  35.0      1      0        S       2
# 4            5         0       3    male  35.0      0      0        S       1

# %%
del titanic["Sex"]
titanic.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch Embarked  Gender
# 0            1         0       3  22.0      1      0        S       1
# 1            2         1       1  38.0      1      0        C       2
# 2            3         1       3  26.0      0      0        S       2
# 3            4         1       1  35.0      1      0        S       2
# 4            5         0       3  35.0      0      0        S       1

# %%
#checking missing values
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Age            177
# SibSp            0
# Parch            0
# Embarked         2
# Gender           0
# dtype: int64

# %% [markdown]
# #### Fill the null values of the Age column.
# #### Fill mean Survived age(mean age of the survived people) in the column where the person has survived and mean not Survived age (mean age of the people who have not survived) in the column where person has not survived

# %%
Survived_mean=titanic[titanic.Survived==1].Age.mean()
Survived_mean
# Out:
# 28.343689655172415

# %% [markdown]
# #### Creating a new "Age" column , filling values in it with a condition if goes True then given values (here meanS) is put in place of last values else nothing happens, simply the values are copied from the "Age" column of the dataset

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch Embarked  Gender
# 0            1         0       3  22.0      1      0        S       1
# 1            2         1       1  38.0      1      0        C       2
# 2            3         1       3  26.0      0      0        S       2
# 3            4         1       1  35.0      1      0        S       2
# 4            5         0       3  35.0      0      0        S       1

# %%
titanic["age"]=np.where(pd.isnull(titanic.Age) & titanic["Survived"]==1, Survived_mean, titanic['Age'])
titanic.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch Embarked  Gender   age
# 0            1         0       3  22.0      1      0        S       1  22.0
# 1            2         1       1  38.0      1      0        C       2  38.0
# 2            3         1       3  26.0      0      0        S       2  26.0
# 3            4         1       1  35.0      1      0        S       2  35.0
# 4            5         0       3  35.0      0      0        S       1  35.0

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Age            177
# SibSp            0
# Parch            0
# Embarked         2
# Gender           0
# age            125
# dtype: int64

# %%
not_Survived_mean=titanic[titanic.Survived==0].Age.mean()
not_Survived_mean
# Out:
# 30.62617924528302

# %%
titanic.age.fillna(not_Survived_mean, inplace=True)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch Embarked  Gender   age
# 0            1         0       3  22.0      1      0        S       1  22.0
# 1            2         1       1  38.0      1      0        C       2  38.0
# 2            3         1       3  26.0      0      0        S       2  26.0
# 3            4         1       1  35.0      1      0        S       2  35.0
# 4            5         0       3  35.0      0      0        S       1  35.0

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Age            177
# SibSp            0
# Parch            0
# Embarked         2
# Gender           0
# age              0
# dtype: int64

# %%
del titanic['Age']
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch Embarked  Gender   age
# 0            1         0       3      1      0        S       1  22.0
# 1            2         1       1      1      0        C       2  38.0
# 2            3         1       3      0      0        S       2  26.0
# 3            4         1       1      1      0        S       2  35.0
# 4            5         0       3      0      0        S       1  35.0

# %% [markdown]
# #### We want to check if "Embarked" column is is important for analysis or not, that is whether survival of the person depends on the Embarked column value or not

# %%
# Finding the number of people who have survived 
# given that they have embarked or boarded from a particular port

survivedQ = titanic[titanic.Embarked == 'Q'][titanic.Survived==1].shape[0]
survivedC = titanic[titanic.Embarked == 'C'][titanic.Survived==1].shape[0]
survivedS = titanic[titanic.Embarked == 'S'][titanic.Survived==1].shape[0]

print(survivedQ)
print(survivedC)
print(survivedS)
# Out:
# 30
# 93
# 217
# C:\Users\Neha\AppData\Local\Temp\ipykernel_1784\647560254.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   survivedQ = titanic[titanic.Embarked == 'Q'][titanic.Survived==1].shape[0]
# C:\Users\Neha\AppData\Local\Temp\ipykernel_1784\647560254.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   survivedC = titanic[titanic.Embarked == 'C'][titanic.Survived==1].shape[0]
# C:\Users\Neha\AppData\Local\Temp\ipykernel_1784\647560254.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   survivedS = titanic[titanic.Embarked == 'S'][titanic.Survived==1].shape[0]

# %%
N_SurvivedQ=titanic[titanic.Embarked=='Q'][titanic.Survived==0].shape[0]
N_SurvivedC=titanic[titanic.Embarked=='C'][titanic.Survived==0].shape[0]
N_SurvivedS=titanic[titanic.Embarked=='S'][titanic.Survived==0].shape[0]

print(N_SurvivedQ)
print(N_SurvivedC)
print(N_SurvivedS)
# Out:
# 47
# 75
# 427
# C:\Users\Neha\AppData\Local\Temp\ipykernel_1784\3886282542.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   N_SurvivedQ=titanic[titanic.Embarked=='Q'][titanic.Survived==0].shape[0]
# C:\Users\Neha\AppData\Local\Temp\ipykernel_1784\3886282542.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   N_SurvivedC=titanic[titanic.Embarked=='C'][titanic.Survived==0].shape[0]
# C:\Users\Neha\AppData\Local\Temp\ipykernel_1784\3886282542.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   N_SurvivedS=titanic[titanic.Embarked=='S'][titanic.Survived==0].shape[0]

# %% [markdown]
# As there are significant changes in the survival rate based on which port the passengers aboard the ship.
# We cannot delete the whole embarked column(It is useful).
# Now the Embarked column has some null values in it and hence we can safely say that deleting some rows from total rows will not affect the result. So rather than trying to fill those null values with some vales. We can simply remove them.

# %%
titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# SibSp          0
# Parch          0
# Embarked       2
# Gender         0
# age            0
# dtype: int64

# %%
titanic.dropna(inplace=True)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch Embarked  Gender   age
# 0            1         0       3      1      0        S       1  22.0
# 1            2         1       1      1      0        C       2  38.0
# 2            3         1       3      0      0        S       2  26.0
# 3            4         1       1      1      0        S       2  35.0
# 4            5         0       3      0      0        S       1  35.0

# %%
titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# SibSp          0
# Parch          0
# Embarked       0
# Gender         0
# age            0
# dtype: int64

# %%
#Renaming "age" and "gender" columns
titanic.rename(columns={'age':'Age'}, inplace=True)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch Embarked  Gender   Age
# 0            1         0       3      1      0        S       1  22.0
# 1            2         1       1      1      0        C       2  38.0
# 2            3         1       3      0      0        S       2  26.0
# 3            4         1       1      1      0        S       2  35.0
# 4            5         0       3      0      0        S       1  35.0

# %%
titanic.rename(columns={"Gender":"Sex"},inplace=True)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch Embarked  Sex   Age
# 0            1         0       3      1      0        S    1  22.0
# 1            2         1       1      1      0        C    2  38.0
# 2            3         1       3      0      0        S    2  26.0
# 3            4         1       1      1      0        S    2  35.0
# 4            5         0       3      0      0        S    1  35.0

# %%
def getEmb(str):
    if str=="S":
        return 1
    elif str=="Q":
        return 2
    else:
        return 3
    
titanic['Embark']=titanic["Embarked"].apply(getEmb)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch Embarked  Sex   Age  Embark
# 0            1         0       3      1      0        S    1  22.0       1
# 1            2         1       1      1      0        C    2  38.0       3
# 2            3         1       3      0      0        S    2  26.0       1
# 3            4         1       1      1      0        S    2  35.0       1
# 4            5         0       3      0      0        S    1  35.0       1

# %%
del titanic['Embarked']
titanic.rename(columns={'Embark':'Embarked'}, inplace=True)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch  Sex   Age  Embarked
# 0            1         0       3      1      0    1  22.0         1
# 1            2         1       1      1      0    2  38.0         3
# 2            3         1       3      0      0    2  26.0         1
# 3            4         1       1      1      0    2  35.0         1
# 4            5         0       3      0      0    1  35.0         1

# %%
#Drawing a pie chart for number of males and females aboard

import matplotlib.pyplot as plt
from matplotlib import style

males = (titanic['Sex']==1).sum()
female= (titanic['Sex']==2).sum()

print(males)
print(female)

p= [males, female]
plt.pie(p,  
       labels =['Male', 'Female'],
       colors =['lightskyblue', 'pink'],
       explode =(0.15, 0),
       startangle = 0)

plt.axis('equal')
plt.show()
# Out:
# 577
# 312

# %%
MaleS=titanic[titanic.Sex==1][titanic.Survived==1].shape[0]
print(MaleS)
MaleN=titanic[titanic.Sex==1][titanic.Survived==0].shape[0]
print(MaleN)
FemaleS=titanic[titanic.Sex==2][titanic.Survived==1].shape[0]
print(FemaleS)
FemaleN=titanic[titanic.Sex==2][titanic.Survived==0].shape[0]
print(FemaleN)
# Out:
# 109
# 468
# 231
# 81
# C:\Users\Neha\AppData\Local\Temp\ipykernel_1784\1146379883.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   MaleS=titanic[titanic.Sex==1][titanic.Survived==1].shape[0]
# C:\Users\Neha\AppData\Local\Temp\ipykernel_1784\1146379883.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   MaleN=titanic[titanic.Sex==1][titanic.Survived==0].shape[0]
# C:\Users\Neha\AppData\Local\Temp\ipykernel_1784\1146379883.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   FemaleS=titanic[titanic.Sex==2][titanic.Survived==1].shape[0]
# C:\Users\Neha\AppData\Local\Temp\ipykernel_1784\1146379883.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   FemaleN=titanic[titanic.Sex==2][titanic.Survived==0].shape[0]

# %%
chart=[MaleS,MaleN,FemaleS,FemaleN]
colors=['lightskyblue', 'orange','pink','red']
labels=['Survived Male', 'Not Survived Male', 'Survived Female', 'Not Survived Female']
explode=[0,0.05,0,0.1]
plt.pie(chart,labels=labels,colors=colors, explode=explode, startangle=100, counterclock=False, autopct='%.2f%%')
plt.axis('equal')
plt.show()

# %%
#x_test=pd.read_csv("/Users/anirbandutta/Desktop/Machine Learning/test_titanic_x_test.csv")
#x_test.head()
#same for x_test..
