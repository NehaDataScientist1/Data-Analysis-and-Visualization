# %% [markdown]
# # Movie Ratings Analysis (Advanced Visulization)

# %% [markdown]
# ###  Bussiness Usecase:
# Clinet Name: ABC
# 1. Five year onwards Client stopped produce Movie
# 2. 5 lakh budget
# 3. ABC-- NIT(Company 7.30 batch working as Data Analyst.
# 4. We get data from Client
# 5. 2000-2017 (ABC-Client) produce and Direct (Historical dataset)
# 6. ABC client share the dataset to NIT-- NIT shared to you.
# 7. Now we need analysie data and give suggestions to client

# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Neha\\Downloads\\NARESH IT DATA SCIENCE\\IPYNB Files'

# %%
movie= pd.read_csv(r'C:\Users\Neha\Downloads\NARESH IT DATA SCIENCE\FEB\12-23 FEB\14th FEB\MOVIE RATINGS _ ADVANCE VISUALIZATION _ EDA 1\Movie-Rating.csv')

# %%
movie.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movie.shape
# Out:
# (559, 6)

# %%
len(movie)
# Out:
# 559

# %%
movie.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movie.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movie.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movie.columns=['Film', 'Genre', 'CriticRating', 'AudienceRating','BudgetMillions','Year']

# %%
movie.head() # Removed spaces & % removed noise characters
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movie.info(())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movie.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
movie['Year']=movie['Year'].astype('category') # is it real no. year you can take average,min,max but out come have no meaning

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(1), int64(3), object(2)
# memory usage: 22.7+ KB

# %%
movie.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
movie.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movie['Film']
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movie['Film']=movie['Film'].astype('category')

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(2), int64(3), object(1)
# memory usage: 40.0+ KB

# %%
movie['Genre']=movie['Genre'].astype('category')

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movie.describe() 
#now when you see the describt you will get only integer value mean, standard deviation which is meaning full
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %% [markdown]
# #  Using JOINTPLOTS:

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# * basically joint plot is a scatter plot & it find the relation b/w audiene & critics
# * also if you look up you can find the uniform distribution (critics)and normal distriution (audience)

# %%
v1=sns.jointplot(data=movie, x='CriticRating' , y='AudienceRating')
#Audience rating is more dominant then critics rating
# Based on this we find out as most people are most liklihood to watch audience rating & less likely to wathc critics rating
# let me explain the excel - if you filter audience rating & critic rating. critic rating has very low values compare to audience rating

# %%
v2=sns.jointplot(data=movie, x='CriticRating' , y='AudienceRating' , kind='scatter', aspect =1)
#kind : { "scatter" | "kde" | "hist" | "hex" | "reg" | "resid" }
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 v2=sns.jointplot(data=movie, x='CriticRating' , y='AudienceRating' , kind='scatter', aspect =1)
#
# NameError: name 'sns' is not defined

# %%
v3=sns.jointplot(data=movie, x='CriticRating' , y='AudienceRating' , kind='kde')
#kind : { "scatter" | "kde" | "hist" | "hex" | "reg" | "resid" }

# %%
v4=sns.jointplot(data=movie, x='CriticRating' , y='AudienceRating' , kind='hist')
#kind : { "scatter" | "kde" | "hist" | "hex" | "reg" | "resid" }

# %%
v5=sns.jointplot(data=movie, x='CriticRating' , y='AudienceRating' , kind='hex')
#kind : { "scatter" | "kde" | "hist" | "hex" | "reg" | "resid" }

# %%
v6=sns.jointplot(data=movie, x='CriticRating' , y='AudienceRating' , kind='reg')
#kind : { "scatter" | "kde" | "hist" | "hex" | "reg" | "resid" }

# %%
v7=sns.jointplot(data=movie, x='CriticRating' , y='AudienceRating' , kind='resid')
#kind : { "scatter" | "kde" | "hist" | "hex" | "reg" | "resid" }

# %% [markdown]
# # Histogram:

# %% [markdown]
# ####  distplot using sns

# %%
#<<< chat1

m1= sns.distplot(movie['AudienceRating'])
#y - axis generated by seaborn automatically that is the powefull of seaborn gallery

# %%
sns.set_style('darkgrid')
m2= sns.distplot(movie['AudienceRating'], bins=100)
# style : dict, or one of {darkgrid, whitegrid, dark, white, ticks}

# %%
sns.set_style('dark')
m3= sns.distplot(movie['AudienceRating'], bins=100)
# style : dict, or one of {darkgrid, whitegrid, dark, white, ticks}

# %%
sns.set_style('ticks')
m4= sns.distplot(movie['AudienceRating'], bins=100)
# style : dict, or one of {darkgrid, whitegrid, dark, white, ticks}

# %% [markdown]
#  ###  hist using plt

# %%
n1= plt.hist(movie['CriticRating'], bins=15)

# %%
# <<< chat - 2
# Creating stacked histograms & this is bit tough to understand

# %%
#h1 = plt.hist(movies.BudgetMillions)

plt.hist(movie.BudgetMillions)
# Out:
# (array([237., 162.,  75.,  28.,  17.,  20.,  13.,   3.,   3.,   1.]),
#  array([  0.,  30.,  60.,  90., 120., 150., 180., 210., 240., 270., 300.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(movie[movie.Genre=='Drama'].BudgetMillions)
plt.show()

# %%
plt.hist(movie[movie.Genre=='Comedy'].BudgetMillions)
plt.show()

# %%
plt.hist(movie[movie.Genre=='Romance'].BudgetMillions)
plt.show()

# %%
movie.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
#movies.Genre.unique()

# %%
# Below plots are stacked histogram becuase overlaped

# %%
plt.hist(movie[movie.Genre=='Action'].BudgetMillions, bins=20)
plt.hist(movie[movie.Genre=='Thriller'].BudgetMillions, bins=20)
plt.hist(movie[movie.Genre=='Drama'].BudgetMillions, bins=20)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.hist([  movie[movie.Genre=='Action'].BudgetMillions,\
            movie[movie.Genre=='Drama'].BudgetMillions, \
            movie[movie.Genre=='Thriller '].BudgetMillions,\
            movie[movie.Genre=='Comedy'].BudgetMillions], 
         bins=20, stacked=True)
# Out:
# (array([[  7.,  22.,  27.,  16.,   8.,  16.,   9.,   5.,   7.,   6.,  12.,
#            2.,   3.,   8.,   1.,   2.,   1.,   1.,   0.,   1.],
#         [ 32.,  62.,  45.,  24.,  14.,  18.,  10.,   5.,   7.,   6.,  13.,
#            2.,   3.,   8.,   1.,   2.,   1.,   1.,   0.,   1.],
#         [ 32.,  62.,  45.,  24.,  14.,  18.,  10.,   5.,   7.,   6.,  13.,
#            2.,   3.,   8.,   1.,   2.,   1.,   1.,   0.,   1.],
#         [ 62., 116.,  81.,  42.,  28.,  32.,  14.,   6.,   7.,   6.,  13.,
#            3.,   3.,   8.,   1.,   2.,   1.,   1.,   0.,   1.]]),
#  array([  0.,  15.,  30.,  45.,  60.,  75.,  90., 105., 120., 135., 150.,
#         165., 180., 195., 210., 225., 240., 255., 270., 285., 300.]),
#  <a list of 4 BarContainer objects>)

# %%
# if you have 100 categories you cannot copy & paste all the things

for gen in movie.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %% [markdown]
# # lmplot:

# %%
a1=sns.lmplot(data=movie, x='CriticRating', y='AudienceRating',\
                 fit_reg=False, aspect=1)

# %%
a2=sns.lmplot(data=movie, x='CriticRating', y='AudienceRating',\
                 fit_reg=False, hue='Genre' , aspect=2)

# %%
movie.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
a2=sns.lmplot(data=movie, x='CriticRating', y='AudienceRating',fit_reg=False, hue='Genre',height=10 )

# %% [markdown]
# # Kernal Density Estimate plot ( KDE PLOT)
# #how can i visulize audience rating & critics rating . using scatterplot

# %%
#k1 = sns.kdeplot(movie.CriticRating,movie.AudienceRating)
sns.kdeplot(data=movie, x='CriticRating', y='AudienceRating')

# where do u find more density and how density is distibuted across from the the chat 
# center point is kernal this is calld KDE & insteade of dots it visualize like this
# we can able to clearly see the spread at the audience ratings)
# Out:
# <Axes: xlabel='CriticRating', ylabel='AudienceRating'>

# %%
k1 = sns.kdeplot(data=movie, x='CriticRating', y='AudienceRating',shade = True,shade_lowest=False,cmap='Reds')

# %%
k1 = sns.kdeplot(data=movie, x='CriticRating', y='AudienceRating',shade_lowest=False,cmap='Greens_r')

# %%
sns.set_style('dark')
k1 = sns.kdeplot(data=movie, x='BudgetMillions', y='AudienceRating',shade_lowest=False,cmap='Greens_r')

# %%
sns.style='dark'
k1=sns.kdeplot(data=movie,x='BudgetMillions',y='AudienceRating')

# %%
k2 = sns.kdeplot(data=movie,x='BudgetMillions',y='CriticRating')

# %% [markdown]
# # Subplots:

# %%
ax=plt.subplots(1,2, figsize=(12,6))

# %%
f, axes = plt.subplots(1,2, figsize =(12,6))

k1 = sns.kdeplot(data=movie,x='BudgetMillions',y='CriticRating',ax=axes[0], shade = True,shade_lowest=False,cmap='Reds')
k2 = sns.kdeplot(data=movie,x='BudgetMillions',y='CriticRating',ax = axes[1], shade = True,shade_lowest=False,cmap='Greens_r')

# %%
ax=plt.subplots(3,3, figsize=(12,6))

# %%
axes
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %% [markdown]
# # Box plot:

# %%
w= sns.boxplot(data=movie, x='Genre', y = 'CriticRating')

# %% [markdown]
# # Violinplot:

# %%
z= sns.violinplot(data=movie,x='Genre', y = 'CriticRating')

# %%
w1=sns.boxplot(data=movie[movie['Genre']=='Drama'],  x='Year', y = 'CriticRating')

# %%
z = sns.violinplot(data=movie[movie.Genre == 'Drama'], x='Year', y = 'CriticRating')

# %% [markdown]
# # Createing a Facet grid

# %%
g= sns.FacetGrid(movie, row='Genre', col='Year')
#kind of subplots

# %%
g= sns.FacetGrid(movie, row='Genre', col='Year', hue='Genre')
#kind of subplots

# %%
plt.scatter(movie.CriticRating,movie.AudienceRating)

# %%
g= sns.FacetGrid(movie, row='Genre', col='Year', hue= 'Genre')
g= g.map(plt.scatter,'CriticRating', 'AudienceRating' )
#scatterplots are mapped in facetgrid

# %%
# you can populated any type of chat.

# %%
g= sns.FacetGrid(movie, row='Genre', col='Year', hue='Genre')
g=g.map(plt.hist,'BudgetMillions')
#scatterplots are mapped in facetgrid

# %%
#
g =sns.FacetGrid (movie, row = 'Genre', col = 'Year', hue = 'Genre')
kws = dict(s=50, linewidth=0.5,edgecolor='black')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating',**kws ) #scatterplots are mapped in facetgrid

# %% [markdown]
# #  Final suggestions we can give to client: ABC:
#
#
# #### 1. Our Analysis suggested that ACTION , COMEDY, DRAMA and HORROR movie are top audience rated movies.
#
# #### 2. ACTION/COMEDY is finaly suggested as per client budgest as these movies made in low budgest and high ratings.
#
# ## so go with ACTIONS and COMEDY it will definately a HIT movie.

# %%
# python is not vectorize programming language
# Building dashboards (dashboard - combination of chats)
import matplotlib.pyplot as plt

sns.set_style('darkgrid')
f, axes = plt.subplots (2,2, figsize = (15,15))

# %%
sns.set_style('dark')
f, axes = plt.subplots (2,2, figsize = (15,15))



k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))




k1 = sns.kdeplot(data=movie,x='BudgetMillions',y='CriticRating',ax=axes[0,0], cmap = 'inferno')
k2 = sns.kdeplot(data=movie,x='BudgetMillions',y='CriticRating',ax=axes[0,1])
k3 = sns.violinplot(data=movie[movie.Genre=='Drama'], x='Year', y = 'CriticRating', ax=axes[1,0])
k4b = sns.kdeplot(data=movie,x='CriticRating',y='AudienceRating',shade = True,shade_lowest=False,cmap='Reds',ax = axes[1,1])
k4a = sns.kdeplot(data=movie,x='CriticRating',y='AudienceRating',shade = True,shade_lowest=False,cmap='Reds',ax=axes[1,1])



plt.show()

# %%
# How can you style your dashboard  using different color map

# python is not vectorize programming language
# Building dashboards (dashboard - combination of chats)

sns.set_style('dark',{'axes.facecolor':'black'})
f, axes = plt.subplots (2,2, figsize = (15,15))

#plot [0,0]
k1 = sns.kdeplot(data=movie,x='BudgetMillions',y='AudienceRating',\
                 shade = True, shade_lowest=True,cmap = 'inferno', \
                 ax = axes[0,0])
k1b = sns.kdeplot(data=movie,x='BudgetMillions',y='AudienceRating', \
                 cmap = 'cool',ax = axes[0,0])

#plot [0,1]
k2 = sns.kdeplot(data=movie,x='BudgetMillions',y='CriticRating',\
                 shade=True, shade_lowest=True, cmap='inferno',\
                 ax = axes[0,1])
k2b = sns.kdeplot(data=movie,x='BudgetMillions',y='CriticRating',\
                  cmap = 'cool', ax = axes[0,1])

#plot[1,0]
z = sns.violinplot(data=movie[movie.Genre=='Drama'], \
                   x='Year', y = 'CriticRating', ax=axes[1,0])

#plot[1,1]
k4 = sns.kdeplot(data=movie,x='CriticRating',y='AudienceRating', \
                 shade = True,shade_lowest=False,cmap='Blues_r', \
                 ax=axes[1,1])

k4b = sns.kdeplot(data=movie,x='CriticRating',y='AudienceRating', \
                  cmap='gist_gray_r',ax = axes[1,1])


k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

plt.show()

# %% [markdown]
# Final discussion what we learn so far -
# 1. category datatype in python
# 2.  jointplots
# 3.  histogram
# 4.  stacked histograms
# 5.  Kde plot
# 6.  subplot
# 7.  violin plots
# 8. Factet grid
# 9.  Building dashboards
